# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a lsit of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot.
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot
plt.plot(x_axis, y_axis)
plt.show()

# %%
# Create a plot and add a label for the legend.
plt.plot(x_axis, y_axis, label = 'Boston')

# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")

# Set the y limit between 0 and 45
plt.ylim(0, 45)

#Create a title.
plt.title("PyBer Fare by Month")

#Add the legend
plt.legend()

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')

#Create labels for x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")

# Set the y limmit to 0 and 45
plt.ylim(0, 45)

# Create a title
plt.title("PyBer Fare By Month")

# Add a grid
plt.grid()

#Add the legend.
plt.legend()

# %%
plt.plot(x_axis, y_axis, marker="<", color="green", linewidth=2, label="Boston")
#Create labels for x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")

# Set the y limmit to 0 and 45
plt.ylim(0, 45)

# Create a title
plt.title("PyBer Fare By Month")

# Add a grid
plt.grid()

#Add the legend.
plt.legend()

# %%
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label="Boston")

# Create labels for the x and y axis
plt.xlabel("Date")
plt.ylabel("Fare($)")

#Create a title.
plt.title("PyBer Fare by Month")

# Add the label.
plt.legend()

# %%
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
# Create the plot.
plt.barh(x_axis, y_axis, color="magenta", label="Boston")
plt.gca().invert_yaxis()

# Create labels for the x and y axis
plt.xlabel("Fare($)")
plt.ylabel("Date")

#Create a title.
plt.title("PyBer Fare by Month")

# Add the label.
plt.legend()

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color="cyan", label="Chicago")
ax.set_title("PyBer Fare by Month")
ax.legend()
ax.set_xlabel("Fare($)")
ax.set_ylabel("Month")
plt.gca().invert_yaxis()

# %%
x = [50, 42, 39, 34, 32, 48, 22, 7, 8, 13]
y = [17, 19, 21, 22, 24, 23, 34, 31, 43, 35]

# %%
plt.scatter(x,y, c="green", marker="x", s=x)
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")
plt.title("Average Fare vs Total Rides")
plt.show()

# %%
plt.plot(x_axis, y_axis, "o")

# %%
# Create the plot.
plt.scatter(x_axis, y_axis, color="red", label="Chicago")
plt.gca().invert_yaxis()

# Create labels for the x and y axis
plt.xlabel("Fare($)")
plt.ylabel("Date")

#Create a title.
plt.title("PyBer Fare by Month")

# Add the label.
plt.legend()

# %%
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)

# %%
plt.scatter(x_axis, y_axis, y_axis_larger)

# %%
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
# OOP
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
# OOP Buble chart
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, c="skyblue", label="Boston")
    
ax.set_title("PyBer Fare by Month")
ax.legend()
ax.set_xlabel("Fare($)")
ax.set_ylabel("Month")
plt.gca().invert_yaxis()

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
# Assign 12 colors, one for each month
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
plt.subplots(figsize=(8, 8))
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0,)
plt.pie(y_axis, 
        explode=explode_values, 
        colors=colors,
        labels=x_axis, 
        autopct='%.1f%%')

plt.show()

# %%
# OOP
fig, ax = plt.subplots()
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
ax.pie(y_axis,labels=x_axis)


plt.subplots(figsize=(8, 8))
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)
